# %%
from templateflow import api as tflow

dseg = tflow.get(
    "MNI152NLin2009cAsym",
    resolution=1,
    atlas="Schaefer2018",
    desc="200Parcels7Networks",
    suffix="dseg",
    extension="nii.gz",
)
tsv = tflow.get(
    "MNI152NLin2009cAsym",
    atlas="Schaefer2018",
    desc="200Parcels7Networks",
    suffix="dseg",
    extension="tsv",
)

print(dseg)
print(tsv)
