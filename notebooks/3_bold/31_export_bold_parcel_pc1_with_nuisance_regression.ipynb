# %% [markdown]
# # Compatibility Note
#
# Use the active public notebook instead:
#
# - step31_export_bold_parcel_pc1_with_nuisance_regression.ipynb
#
# This older filename is kept only as a compatibility pointer.
